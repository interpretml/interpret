# %% [markdown]
# # APLRRegressor
#
# Link to Algorithm description: [Automatic Piecewise Linear Regression](../../aplr.ipynb)
#
# The below API reference describes the methods added by the light wrapper in `InterpretML`. The API reference for the remaining members and methods can be found [here](https://github.com/ottenbreit-data-science/aplr/blob/main/API_REFERENCE_FOR_REGRESSION.md)
#
# ```{eval-rst}
# .. autoclass:: interpret.glassbox.APLRRegressor
#    :members:
#    :inherited-members:
# ```
